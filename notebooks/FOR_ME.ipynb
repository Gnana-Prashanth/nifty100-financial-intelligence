# %%
import pandas as pd

companies = pd.read_excel(
    r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\companies.xlsx",
    header=1
)

master_ids = set(companies["id"])
print(master_ids)
print(len(master_ids),"unique ids in companies.xlsx")

pl_ids = set(
    pd.read_excel(
        r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\profitandloss.xlsx",
        header=1
    )["company_id"]
)
print("\n",pl_ids)
print(len(pl_ids),"unique ids in profitandloss.xlsx")

# Find IDs in pl_ids that are not in master_ids
extras = sorted(pl_ids - master_ids)

# Show the list
print("\n", extras)

# Show how many extras there are
print(len(extras), "extra ids that are not in companies.xlsx")
# Out:
# {'PIDILITIND', 'DIVISLAB', 'JIOFIN', 'ADANIPORTS', 'CANBK', 'LTIM', 'HAVELLS', 'PFC', 'DMART', 'TATAPOWER', 'JINDALSTEL', 'APOLLOHOSP', 'BAJAJ-AUTO', 'BHEL', 'TATASTEEL', 'DLF', 'ONGC', 'ADANIPOWER', 'AXISBANK', 'JSWENERGY', 'PNB', 'SHREECEM', 'LT', 'DRREDDY', 'TRENT', 'JSWSTEEL', 'RELIANCE', 'TVSMOTOR', 'BAJAJHLDNG', 'RECLTD', 'ICICIPRULI', 'HINDUNILVR', 'SUNPHARMA', 'ADANIGREEN', 'ASIANPAINT', 'ITC', 'SBIN', 'LICI', 'MOTHERSON', 'BPCL', 'IRFC', 'NAUKRI', 'NESTLEIND', 'TECHM', 'BANKBARODA', 'TORNTPHARM', 'IRCTC', 'M&M', 'LODHA', 'ADANIENSOL', 'HAL', 'ATGL', 'ICICIBANK', 'SHRIRAMFIN', 'AMBUJACEM', 'IOC', 'KOTAKBANK', 'GAIL', 'HCLTECH', 'BOSCHLTD', 'TATAMOTORS', 'CHOLAFIN', 'EICHERMOT', 'BRITANNIA', 'INDUSINDBK', 'BEL', 'ADANIENT', 'SIEMENS', 'GRASIM', 'BAJAJFINSV', 'TCS', 'CIPLA', 'POWERGRID', 'TATACONSUM', 'DABUR', 'COALINDIA', 'BHARTIARTL', 'HDFCLIFE', 'NTPC', 'BAJFINANCE', 'INFY', 'HINDALCO', 'HDFCBANK', 'MARUTI', 'ICICIGI', 'INDIGO', 'GODREJCP', 'TITAN', 'SBILIFE', 'ABB', 'NHPC',
# ...

# %%
import pandas as pd

companies = pd.read_excel(
    r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\companies.xlsx",
    header=1
)

master_ids = set(companies["id"])
print(master_ids)
print(len(master_ids))

pl_ids = set(
    pd.read_excel(
        r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\balancesheet.xlsx",
        header=1
    )["company_id"]
)
print("\n",pl_ids)
print(len(pl_ids))

print("\n",sorted(pl_ids - master_ids))
# Out:
# {'HAL', 'SHRIRAMFIN', 'ICICIPRULI', 'GODREJCP', 'PFC', 'NESTLEIND', 'PNB', 'TATASTEEL', 'JSWENERGY', 'ADANIPORTS', 'DABUR', 'LT', 'ADANIENSOL', 'APOLLOHOSP', 'HDFCLIFE', 'GAIL', 'BPCL', 'AMBUJACEM', 'AXISBANK', 'CIPLA', 'ICICIBANK', 'CANBK', 'LTIM', 'BHEL', 'IRCTC', 'TECHM', 'M&M', 'BHARTIARTL', 'IRFC', 'ADANIGREEN', 'CHOLAFIN', 'MARUTI', 'TORNTPHARM', 'JIOFIN', 'TATACONSUM', 'ATGL', 'ADANIPOWER', 'SBIN', 'DMART', 'TRENT', 'TITAN', 'SBILIFE', 'ASIANPAINT', 'BAJAJFINSV', 'HAVELLS', 'ITC', 'ONGC', 'ICICIGI', 'DLF', 'LICI', 'HCLTECH', 'DIVISLAB', 'MOTHERSON', 'NAUKRI', 'NTPC', 'COALINDIA', 'HINDUNILVR', 'EICHERMOT', 'ADANIENT', 'BANKBARODA', 'IOC', 'TATAPOWER', 'BRITANNIA', 'JSWSTEEL', 'TCS', 'RELIANCE', 'TATAMOTORS', 'BOSCHLTD', 'PIDILITIND', 'HINDALCO', 'INDUSINDBK', 'INDIGO', 'ABB', 'LODHA', 'SHREECEM', 'NHPC', 'BAJAJ-AUTO', 'BAJFINANCE', 'RECLTD', 'HDFCBANK', 'DRREDDY', 'POWERGRID', 'GRASIM', 'KOTAKBANK', 'TVSMOTOR', 'HEROMOTOCO', 'JINDALSTEL', 'INFY', 'BAJAJHLDNG', 'SIEMENS', 'BEL'
# ...

# %%
import pandas as pd
analysis = pd.read_excel(r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\analysis.xlsx",header=1)
documents = pd.read_excel(r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\documents.xlsx",header=1)
prosandcons = pd.read_excel(r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\prosandcons.xlsx",header=1)
cashflow = pd.read_excel(r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\cashflow.xlsx",header=1)

# %%
print(analysis.columns)
print(documents.columns)
print(prosandcons.columns)
# Out:
# Index(['id', 'company_id', 'compounded_sales_growth',
#        'compounded_profit_growth', 'stock_price_cagr', 'roe'],
#       dtype='object')
# Index(['id', 'company_id', 'Year', 'Annual_Report'], dtype='object')
# Index(['id', 'company_id', 'pros', 'cons'], dtype='object')

# %%
print(analysis.duplicated().sum())
print(documents.duplicated().sum())
print(prosandcons.duplicated().sum())
print(cashflow.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
analysis.head()
# Out:
#    id company_id         compounded_sales_growth  compounded_profit_growth  \
# 0   1   HDFCBANK                   10 Years: 21%             10 Years: 22%
# 1  10    SBILIFE              5 Years:       24%    5 Years:            6%
# 2  11    SBILIFE              3 Years:       17%    3 Years:            9%
# 3  12    SBILIFE             TTM:            43%  TTM:                 18%
# 4  13        TCS  10 Years:     11%                  10 Years:          9%
#
#            stock_price_cagr                   roe
# 0         10 Years:     15%     10 Years:     17%
# 1         5 Years:       8%  5 Years          14%
# 2         3 Years:       7%  3 Years:         13%
# 3       1 Year:         -2%   Last Year:      12%
# 4        10 Years:      14%   10 Years:       40%

# %%
sectors = pd.read_excel(
    r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\supporting\sectors.xlsx",
    header=0
)

sectors.head()
# Out:
#    id  company_id broad_sector         sub_sector  index_weight_pct  \
# 0   1         ABB  Industrials      Capital Goods              0.81
# 1   2  ADANIENSOL       Energy  Power & Utilities              0.65
# 2   3    ADANIENT  Industrials      Conglomerates              1.50
# 3   4  ADANIGREEN       Energy   Renewable Energy              1.23
# 4   5  ADANIPORTS  Industrials     Infrastructure              2.12
#
#   market_cap_category
# 0           Large Cap
# 1           Large Cap
# 2           Large Cap
# 3           Large Cap
# 4           Large Cap

# %%
stock_prices = pd.read_excel(
    r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\supporting\stock_prices.xlsx",
    header=0
)

stock_prices.head()
# Out:
#    id company_id        date  open_price  high_price  low_price  close_price  \
# 0   1        ABB  2020-01-01     1958.61     2150.53    1835.28      1964.30
# 1   2        ABB  2020-02-01     2177.03     2192.92    1931.08      2165.21
# 2   3        ABB  2020-03-01     2221.26     2440.28    1995.23      2198.78
# 3   4        ABB  2020-04-01     1932.02     2027.44    1740.12      1958.56
# 4   5        ABB  2020-05-01     2089.00     2290.96    1878.23      2085.72
#
#      volume  adjusted_close
# 0  26184368         1964.30
# 1   1668316         2165.21
# 2  20578107         2198.78
# 3  14558597         1958.56
# 4  44638694         2085.72

# %%
financial_ratios = pd.read_excel(
    r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\supporting\financial_ratios.xlsx",
    header=0
)

financial_ratios.head()
# Out:
#    id company_id      year  net_profit_margin_pct  \
# 0   1        ABB  Dec 2012                   8.77
# 1   2        ABB  Mar 2014                   8.70
# 2   3        ABB  Mar 2014                   8.70
# 3   4        ABB  Mar 2015                  10.00
# 4   5        ABB  Mar 2015                  10.00
#
#    operating_profit_margin_pct  return_on_equity_pct  debt_to_equity  \
# 0                         12.0                 22.41             0.0
# 1                         12.0                 25.13             0.0
# 2                         12.0                 25.13             0.0
# 3                         14.0                 24.44             0.0
# 4                         14.0                 24.44             0.0
#
#    interest_coverage  asset_turnover  free_cash_flow_cr  capex_cr  \
# 0                NaN          1.8225               42.0      59.0
# 1                NaN          1.9982               11.0     144.0
# ...

# %%
df.columns = df.columns.str.strip()

print(df.columns)df.columns = df.columns.str.strip()

print(df.columns)

# %%
print(
    financial_ratios.duplicated(
        subset=["company_id", "year"]
    ).sum()
)
# Out:
# 119

# %%
dups = financial_ratios[
    financial_ratios.duplicated(
        subset=["company_id", "year"],
        keep=False
    )
]

print(
    dups[
        ["company_id", "year"]
    ].sort_values(
        ["company_id", "year"]
    )
)
# Out:
#      company_id      year
# 1           ABB  Mar 2014
# 2           ABB  Mar 2014
# 3           ABB  Mar 2015
# 4           ABB  Mar 2015
# 5           ABB  Mar 2016
# ...         ...       ...
# 1095      TECHM  Mar 2022
# 1096      TECHM  Mar 2023
# 1097      TECHM  Mar 2023
# 1098      TECHM  Mar 2024
# 1099      TECHM  Mar 2024
#
# [202 rows x 2 columns]

# %%
pl = pd.read_excel(
    r"C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\raw\profitandloss.xlsx",
    header=1
)

print(pl.shape)

pl = pl.drop_duplicates(
    subset=["company_id", "year"]
)

print(pl.shape)
# Out:
# (1276, 15)
# (1263, 15)

# %%
pl.head(2)
# Out:
#    id company_id      year  sales  expenses  operating_profit  opm_percentage  \
# 0  61        ABB  Dec 2012   1653      1451             202.0            12.0
# 1  62        ABB  Mar 2014   2276      2009             267.0            12.0
#
#    other_income  interest  depreciation  profit_before_tax  tax_percentage  \
# 0            33         0            19                215            33.0
# 1            49         0            22                295            33.0
#
#    net_profit   eps  dividend_payout
# 0         145  68.0             25.0
# 1         198  93.0             25.0

# %%
pg = pd.read_excel(r'C:\Users\Prashanth Reddy\Desktop\vs code\Nifty100_Financial_Intelligence\data\supporting\peer_groups.xlsx')
pg.head()
print(pg["company_id"].duplicated().sum())
# Out:
# 0
